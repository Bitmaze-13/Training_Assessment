# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("customer_churn_synthetic.csv")

df.head()
# Out:
#    CustomerID  Gender  SeniorCitizen Partner Dependents           Region  \
# 0      100000    Male              0      No        Yes          Chennai
# 1      100001  Female              0      No        Yes  Bengaluru North
# 2      100002    Male              1      No         No          Chennai
# 3      100003    Male              0     Yes         No  Bengaluru North
# 4      100004    Male              1     Yes         No        Hyderabad
#
#   InternetService OnlineSecurity TechSupport OnlineBackup  ...  \
# 0             DSL            Yes         Yes          Yes  ...
# 1     Fiber optic            Yes         Yes           No  ...
# 2             NaN             No          No           No  ...
# 3     Fiber optic            Yes         Yes           No  ...
# 4             DSL             No          No           No  ...
#
#   PaperlessBilling            PaymentMethod TenureMonths MonthlyCharges  \
# 0              Yes         Electronic check           23          74.20
# 1               No  Credit card (automatic)           52          90.27
# 2              Yes         Electronic check           27          16.62
# 3               No             Mailed check           10          77.30
# 4              Yes             Mailed check           61          46.59
#
#   TotalCharges     AccountStartDate       AccountEndDate  Churn  \
# 0      1705.97  2023-05-13 17:59:02                  NaN     No
# 1      4644.31  2022-03-29 03:40:24  2026-01-13 00:00:00    Yes
# 2       491.96  2025-10-25 15:11:53  2026-01-13 00:00:00    Yes
# 3       814.32  2023-06-03 21:51:03  2025-12-27 21:51:03    Yes
# 4      2845.61  2022-08-10 05:42:51  2026-01-13 00:00:00    Yes
#
#   ChurnProbability       ChurnReason
# 0            0.378               NaN
# 1            0.378  Competitor offer
# 2            0.891    Service issues
# 3            0.550    Service issues
# 4            0.818  Payment problems
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        10000 non-null  int64
#  1   Gender            10000 non-null  object
#  2   SeniorCitizen     10000 non-null  int64
#  3   Partner           10000 non-null  object
#  4   Dependents        10000 non-null  object
#  5   Region            10000 non-null  object
#  6   InternetService   8505 non-null   object
#  7   OnlineSecurity    10000 non-null  object
#  8   TechSupport       10000 non-null  object
#  9   OnlineBackup      10000 non-null  object
#  10  StreamingTV       10000 non-null  object
#  11  StreamingMovies   10000 non-null  object
#  12  Contract          10000 non-null  object
#  13  PaperlessBilling  10000 non-null  object
#  14  PaymentMethod     10000 non-null  object
#  15  TenureMonths      10000 non-null  int64
#  16  MonthlyCharges    10000 non-null  float64
#  17  TotalCharges      10000 non-null  float64
#  18  AccountStartDate  10000 non-null  object
#  19  AccountEndDate    6643 non-null   object
#  20  Churn             10000 non-null  object
#  21  ChurnProbability  10000 non-null  float64
#  22  ChurnReason       6643 non-null   object
# dtypes: float64(3), int64(3), object(17)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#          CustomerID  SeniorCitizen  TenureMonths  MonthlyCharges  \
# count   10000.00000   10000.000000  10000.000000    10000.000000
# mean   104999.50000       0.151100     35.329400       64.510621
# std      2886.89568       0.358164     20.618958       22.288727
# min    100000.00000       0.000000      0.000000       15.000000
# 25%    102499.75000       0.000000     17.000000       55.507500
# 50%    104999.50000       0.000000     35.000000       69.175000
# 75%    107499.25000       0.000000     53.000000       80.680000
# max    109999.00000       1.000000     71.000000      108.360000
#
#        TotalCharges  ChurnProbability
# count  10000.000000      10000.000000
# mean    2273.870095          0.659587
# std     1604.037750          0.191746
# min        0.000000          0.130000
# 25%      892.417500          0.525000
# 50%     2033.560000          0.690000
# 75%     3507.955000          0.802000
# max     7072.820000          0.968000

# %%
for cols in df.columns:
    if df[cols].dtype == object:
        print(cols)
        print(df[cols].unique())
# Out:
# Gender
# ['Male' 'Female']
# Partner
# ['No' 'Yes']
# Dependents
# ['Yes' 'No']
# Region
# ['Chennai' 'Bengaluru North' 'Hyderabad' 'Delhi' 'Kolkata' 'Jaipur'
#  'Bengaluru South' 'Pune' 'Mumbai' 'Ahmedabad']
# InternetService
# ['DSL' 'Fiber optic' nan]
# OnlineSecurity
# ['Yes' 'No']
# TechSupport
# ['Yes' 'No']
# OnlineBackup
# ['Yes' 'No']
# StreamingTV
# ['Yes' 'No']
# StreamingMovies
# ['No' 'Yes']
# Contract
# ['One year' 'Month-to-month' 'Two year']
# PaperlessBilling
# ['Yes' 'No']
# PaymentMethod
# ['Electronic check' 'Credit card (automatic)' 'Mailed check'
#  'Bank transfer (automatic)']
# AccountStartDate
# ['2023-05-13 17:59:02' '2022-03-29 03:40:24' '2025-10-25 15:11:53' ...
#  '2019-10-23 01:09:21' '2023-03-16 06:10:41' '2022-11-25 15:29:16']
# AccountEndDate
# [nan '2026-01-13 00:00:00' '2025-12-27 21:51:03' ... '2024-02-25 01:09:21'
#  '2025-01-17 06:10:41' '2024-12-27 15:29:16']
# Churn
# ['No' 'Yes']
# ChurnReason
# [nan 'Competitor offer' 'Service issues' 'Payment problems'
#  'Price too high' 'Relocation']

# %%
df.isna().sum()
# Out:
# CustomerID             0
# Gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# Region                 0
# InternetService     1495
# OnlineSecurity         0
# TechSupport            0
# OnlineBackup           0
# StreamingTV            0
# StreamingMovies        0
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# TenureMonths           0
# MonthlyCharges         0
# TotalCharges           0
# AccountStartDate       0
# AccountEndDate      3357
# Churn                  0
# ChurnProbability       0
# ChurnReason         3357
# dtype: int64

# %%
# imputing values as the values are not known in this case.
features = ["ChurnReason", "InternetService"]
for cols in features:
    df[cols] = df[cols].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# CustomerID             0
# Gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# Region                 0
# InternetService        0
# OnlineSecurity         0
# TechSupport            0
# OnlineBackup           0
# StreamingTV            0
# StreamingMovies        0
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# TenureMonths           0
# MonthlyCharges         0
# TotalCharges           0
# AccountStartDate       0
# AccountEndDate      3357
# Churn                  0
# ChurnProbability       0
# ChurnReason            0
# dtype: int64

# %%
df.dropna()
# Out:
#       CustomerID  Gender  SeniorCitizen Partner Dependents           Region  \
# 1         100001  Female              0      No        Yes  Bengaluru North
# 2         100002    Male              1      No         No          Chennai
# 3         100003    Male              0     Yes         No  Bengaluru North
# 4         100004    Male              1     Yes         No        Hyderabad
# 5         100005  Female              0     Yes        Yes            Delhi
# ...          ...     ...            ...     ...        ...              ...
# 9995      109995  Female              0     Yes         No  Bengaluru South
# 9996      109996    Male              0      No         No           Mumbai
# 9997      109997  Female              0      No         No           Mumbai
# 9998      109998  Female              0      No         No           Mumbai
# 9999      109999    Male              0      No         No        Ahmedabad
#
#      InternetService OnlineSecurity TechSupport OnlineBackup  ...  \
# 1        Fiber optic            Yes         Yes           No  ...
# 2            Unknown             No          No           No  ...
# 3        Fiber optic            Yes         Yes           No  ...
# 4                DSL             No          No           No  ...
# 5        Fiber optic             No         Yes           No  ...
# ...              ...            ...         ...          ...  ...
# 9995     Fiber optic            Yes         Yes           No  ...
# 9996     Fiber optic            Yes          No           No  ...
# 9997     Fiber optic             No          No           No  ...
# 9998     Fiber optic             No          No          Yes  ...
# 9999     Fiber optic            Yes         Yes           No  ...
#
#      PaperlessBilling              PaymentMethod TenureMonths MonthlyCharges  \
# 1                  No    Credit card (automatic)           52          90.27
# 2                 Yes           Electronic check           27          16.62
# 3                  No               Mailed check           10          77.30
# 4                 Yes               Mailed check           61          46.59
# 5                  No  Bank transfer (automatic)           31          80.10
# ...               ...                        ...          ...            ...
# 9995              Yes    Credit card (automatic)           43          86.90
# 9996              Yes    Credit card (automatic)           17          87.13
# 9997              Yes               Mailed check            1          66.13
# 9998               No    Credit card (automatic)           15          81.47
# 9999              Yes           Electronic check           52          88.34
#
#      TotalCharges     AccountStartDate       AccountEndDate  Churn  \
# 1         4644.31  2022-03-29 03:40:24  2026-01-13 00:00:00    Yes
# 2          491.96  2025-10-25 15:11:53  2026-01-13 00:00:00    Yes
# 3          814.32  2023-06-03 21:51:03  2025-12-27 21:51:03    Yes
# 4         2845.61  2022-08-10 05:42:51  2026-01-13 00:00:00    Yes
# 5         2489.35  2022-03-23 01:40:46  2023-09-17 01:40:46    Yes
# ...           ...                  ...                  ...    ...
# 9995      3759.47  2021-10-18 01:25:05  2025-02-22 01:25:05    Yes
# 9996      1485.47  2019-10-19 23:32:21  2020-08-26 23:32:21    Yes
# 9997        71.51  2019-10-23 01:09:21  2024-02-25 01:09:21    Yes
# 9998      1199.01  2023-03-16 06:10:41  2025-01-17 06:10:41    Yes
# 9999      4578.79  2022-11-25 15:29:16  2024-12-27 15:29:16    Yes
#
#      ChurnProbability       ChurnReason
# 1               0.378  Competitor offer
# 2               0.891    Service issues
# 3               0.550    Service issues
# 4               0.818  Payment problems
# 5               0.769  Competitor offer
# ...               ...               ...
# 9995            0.198  Payment problems
# 9996            0.786        Relocation
# 9997            0.891    Service issues
# 9998            0.870    Price too high
# 9999            0.769    Service issues
#
# [6643 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        10000 non-null  int64
#  1   Gender            10000 non-null  object
#  2   SeniorCitizen     10000 non-null  int64
#  3   Partner           10000 non-null  object
#  4   Dependents        10000 non-null  object
#  5   Region            10000 non-null  object
#  6   InternetService   10000 non-null  object
#  7   OnlineSecurity    10000 non-null  object
#  8   TechSupport       10000 non-null  object
#  9   OnlineBackup      10000 non-null  object
#  10  StreamingTV       10000 non-null  object
#  11  StreamingMovies   10000 non-null  object
#  12  Contract          10000 non-null  object
#  13  PaperlessBilling  10000 non-null  object
#  14  PaymentMethod     10000 non-null  object
#  15  TenureMonths      10000 non-null  int64
#  16  MonthlyCharges    10000 non-null  float64
#  17  TotalCharges      10000 non-null  float64
#  18  AccountStartDate  10000 non-null  object
#  19  AccountEndDate    6643 non-null   object
#  20  Churn             10000 non-null  object
#  21  ChurnProbability  10000 non-null  float64
#  22  ChurnReason       10000 non-null  object
# dtypes: float64(3), int64(3), object(17)
# memory usage: 1.8+ MB

# %%
# Starting Label encoding for the Object Variable 
from sklearn.preprocessing import LabelEncoder
cat_cols = df.select_dtypes(include='object').columns
label_encode = LabelEncoder()
for cols in cat_cols:
        df[cols] = label_encode.fit_transform(df[cols])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        10000 non-null  int64
#  1   Gender            10000 non-null  int64
#  2   SeniorCitizen     10000 non-null  int64
#  3   Partner           10000 non-null  int64
#  4   Dependents        10000 non-null  int64
#  5   Region            10000 non-null  int64
#  6   InternetService   10000 non-null  int64
#  7   OnlineSecurity    10000 non-null  int64
#  8   TechSupport       10000 non-null  int64
#  9   OnlineBackup      10000 non-null  int64
#  10  StreamingTV       10000 non-null  int64
#  11  StreamingMovies   10000 non-null  int64
#  12  Contract          10000 non-null  int64
#  13  PaperlessBilling  10000 non-null  int64
#  14  PaymentMethod     10000 non-null  int64
#  15  TenureMonths      10000 non-null  int64
#  16  MonthlyCharges    10000 non-null  float64
#  17  TotalCharges      10000 non-null  float64
#  18  AccountStartDate  10000 non-null  int64
#  19  AccountEndDate    10000 non-null  int64
#  20  Churn             10000 non-null  int64
#  21  ChurnProbability  10000 non-null  float64
#  22  ChurnReason       10000 non-null  int64
# dtypes: float64(3), int64(20)
# memory usage: 1.8 MB

# %%
# Starting the Modelling for The Problem 
# Intial phase Choosing LinearRegression

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

LR = LinearRegression()

X = df.drop(["Churn","ChurnProbability", "ChurnReason"], axis= 1)
y = df["ChurnProbability"]

X_train , X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error
y_preds = LR.predict(X_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_preds))
print("Mean Squared Error:", mean_squared_error(y_test, y_preds))
print("Root Mean Squared Error:", root_mean_squared_error(y_test, y_preds))
print("R^2 Score:", r2_score(y_test, y_preds))
# Out:
# Mean Absolute Error: 0.057056755359813895
# Mean Squared Error: 0.0049071483017894026
# Root Mean Squared Error: 0.07005104069026671
# R^2 Score: 0.8651198442742675

# %%
df.to_csv("customer_churn.csv")
